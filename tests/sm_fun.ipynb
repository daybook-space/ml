# %%
import matplotlib.pyplot as plt
from scipy.special import expit
import numpy as np

# %%
a = np.arange(-1, 1, 0.01)

# %%
plt.plot(a, expit(a*10)-0.5)

# %%
def sm_fun(score, magnitude):
    return expit(score * 10) * magnitude
